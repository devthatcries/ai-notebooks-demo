# %% [markdown]
# <p>Ejemplo sencillo</p>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdacc9c0-dd36-4b7b-8c00-159c08e88377" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdacc9c0-dd36-4b7b-8c00-159c08e88377">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# areas.py  sample_data

# %%
import areas

# %%
areas.area_circulo(9)
# Out:
# 254.4615

# %%
areas.area_cuadrado(8)
# Out:
# 64

# %% [markdown]
# <p>Ejercicio complejo</p>
# <b>Cree un modulo que realice la multiplicación de dos matrices y uselo</b>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44709cd8-7698-4b8f-bd30-c558a606a114" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44709cd8-7698-4b8f-bd30-c558a606a114">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matrix_mult

# %%
matriz_a = [
    [1, 2, 3],
    [4, 5, 6]
]

matriz_b = [
    [7, 8],
    [9, 10],
    [11, 12]
]

# %%
matriz_c = [
    [2, 0, 1],
    [3, 0, 0],
    [5, 1, 1]
]

matriz_d = [
    [1, 0, 1],
    [1, 2, 1],
    [1, 1, 0]
]

# %%
resultado_ab =matrix_mult.multiplicar_matrices(matriz_a, matriz_b)

# %%
resultado_cd =matrix_mult.multiplicar_matrices(matriz_c, matriz_d)

# %%
if resultado_ab != -1:
  # Imprime la matriz resultante
  for fila in resultado_ab:
      print(fila)
else:
  print("Discrepancia entre dimensiones")
# Out:
# [58, 64]
# [139, 154]

# %%
if resultado_cd != -1:
  # Imprime la matriz resultante
  for fila in resultado_cd:
      print(fila)
else:
  print("Discrepancia entre dimensiones")
# Out:
# [3, 1, 2]
# [3, 0, 3]
# [7, 3, 6]
