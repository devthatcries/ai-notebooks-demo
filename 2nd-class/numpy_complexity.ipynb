# %% [markdown]
# <h1>Python común vs NumPy</b>

# %%
import time
import random

# %%
vector1 = [random.randint(0, 100) for _ in range(10000000)]
vector2 = [random.randint(0, 100) for _ in range(10000000)]

# %% [markdown]
# <p>Python</p>

# %%
def producto_punto(vector1, vector2):
    if len(vector1) != len(vector2):
        return -1

    inicio = time.time()

    producto = 0
    for i in range(len(vector1)):
        producto += vector1[i] * vector2[i]

    fin = time.time()

    tiempo = fin - inicio

    return producto, tiempo

# %%
# Ejemplo de uso
resultado, tiempo = producto_punto(vector1, vector2)

# %%
if resultado == -1:
  print("Vectores tienen distinta dimension")
else:
  print(f"El producto punto entre los vectores es: {resultado}")
  print(f"El tiempo de procesamiento fue de: {round(tiempo,6)} segundos")
# Out:
# El producto punto entre los vectores es: 25002902633
# El tiempo de procesamiento fue de: 1.442006 segundos

# %% [markdown]
# <p>NumPy</p>

# %%
import numpy as np

# %%
vector1 = np.array(vector1)
vector2 = np.array(vector2)

# %%
print(vector1.shape)
print(vector2.shape)
# Out:
# (10000000,)
# (10000000,)

# %%
def producto_punto_np(vector1, vector2):
    if vector1.shape[0] != vector2.shape[0]:
       return -1

    inicio = time.time()

    producto = np.dot(vector1, vector2)

    fin = time.time()

    tiempo = fin - inicio

    return producto, tiempo

# %%
# Ejemplo de uso
resultado, tiempo = producto_punto_np(vector1, vector2)

# %%
if resultado == -1:
  print("Vectores tienen distinta dimension")
else:
  print(f"El producto punto entre los vectores es: {resultado}")
  print(f"El tiempo de procesamiento fue de: {round(tiempo,6)} segundos")
# Out:
# El producto punto entre los vectores es: 25002902633
# El tiempo de procesamiento fue de: 0.023617 segundos

# %%
x = np.array([0,np.pi/2,np.pi])

def funcion_densidad(x):
  #TO DO
  #devolver sin(x)
  #result = sin(x) -> ndarray o numpy array
  pass
