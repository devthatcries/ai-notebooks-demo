# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %% [markdown]
# # Read Data

# %% [markdown]
# Use Kaggle USA Real Estate dataset to predict the price of the house. The dataset contains the following columns:
#
# - **brokered by** (categorically encoded agency/broker)
# - **status** (Housing status - a. ready for sale or b. ready to build)
# - **price** (Housing price, it is either the current listing price or recently sold price if the house is sold recently)
# - **bed** (# of beds)
# - **bath** (# of bathrooms)
# - **acre_lot** (Property / Land size in acres)
# - **street** (categorically encoded street address)
# - **city** (city name)
# - **state** (state name)
# - **zip_code** (postal code of the area)
# - **house_size** (house area/size/living space in square feet)
# - **prev_sold_date** (Previously sold date)
# - **prev_sold_price** (Previously sold price)
#
# The goal is to predict the price of the house based on the given features.
#
# URL: https://www.kaggle.com/datasets/ahmedshahriarsakib/usa-real-estate-dataset/code

# %%
import os 

df = pd.read_csv(os.path.join("data", "usa-house-data.csv"))
df.head(5)
# Out:
#    brokered_by    status      price   bed  bath  acre_lot      street  \
# 0   103378.000  for_sale 105000.000 3.000 2.000     0.120 1962661.000
# 1    52707.000  for_sale  80000.000 4.000 2.000     0.080 1902874.000
# 2   103379.000  for_sale  67000.000 2.000 1.000     0.150 1404990.000
# 3    31239.000  for_sale 145000.000 4.000 2.000     0.100 1947675.000
# 4    34632.000  for_sale  65000.000 6.000 2.000     0.050  331151.000
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico   601.000     920.000            NaN
# 1    Adjuntas  Puerto Rico   601.000    1527.000            NaN
# 2  Juana Diaz  Puerto Rico   795.000     748.000            NaN
# 3       Ponce  Puerto Rico   731.000    1800.000            NaN
# 4    Mayaguez  Puerto Rico   680.000         NaN            NaN

# %% [markdown]
# # Data pre-processing

# %% [markdown]
# ## Data cleaning

# %%
# Remove outliers values
df = df[(df["bed"] < 10) & (df["bath"] < 10) & (df["price"] < 10000000) & (df["house_size"] > 10)]

# Remove rows without price
df = df.dropna(subset=["price"])

# Remove rows with price equal to 0
df = df[df["price"] > 0]

# Remove rows with missing values on bed, bath, and house_size
df = df.dropna(subset=["bed", "bath", "house_size", "acre_lot"])

df.describe()
# Out:
#        brokered_by       price         bed        bath    acre_lot  \
# count  1351907.000 1354142.000 1354142.000 1354142.000 1354142.000
# mean     53574.308  536161.494       3.348       2.507      12.430
# std      30460.767  638705.289       1.012       1.091     797.700
# min          0.000       1.000       1.000       1.000       0.000
# 25%      24829.500  239000.000       3.000       2.000       0.140
# 50%      53008.000  375900.000       3.000       2.000       0.210
# 75%      79221.000  599900.000       4.000       3.000       0.460
# max     110142.000 9999999.000       9.000       9.000  100000.000
#
#            street    zip_code  house_size
# count 1350179.000 1354055.000 1354142.000
# mean   931701.796   55272.663    2090.818
# std    533250.237   29424.713    4141.133
# min        63.000     601.000     100.000
# 25%    468477.500   30252.000    1358.000
# 50%    934059.000   55391.000    1808.000
# 75%   1392525.500   83330.000    2464.000
# max   2001321.000   99999.000 1560780.000

# %%
# Remove unnecessary columns for Machine Learning
df = df.drop(
    columns=[
        "prev_sold_date",
        # "street",
        "brokered_by",
        # "zip_code",
        "acre_lot",
    ]
)

# %%
# Because we will predict the price of the house, we will remove houses that are not sold
df = df[df["status"] == "sold"]

# Remove the status column
df = df.drop(columns=["status"])

df.head()
# Out:
#              price   bed  bath      street       city        state  zip_code  \
# 1414374 524900.000 3.000 2.000 1850809.000     Aguada  Puerto Rico   602.000
# 1414376  90000.000 3.000 2.000  141421.000  Aguadilla  Puerto Rico   603.000
# 1414377  22500.000 2.000 1.000 1889894.000     Anasco  Puerto Rico   610.000
# 1414378 168000.000 6.000 4.000 1157317.000     Anasco  Puerto Rico   610.000
# 1414379 200000.000 3.000 1.000 1855411.000    Arecibo  Puerto Rico   612.000
#
#          house_size
# 1414374    2200.000
# 1414376    1421.000
# 1414377     850.000
# 1414378    3422.000
# 1414379     580.000

# %% [markdown]
# ## Data encoding

# %% [markdown]
# ### Label encoding
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html

# %%
from sklearn.preprocessing import LabelEncoder

# Label encoder city
df["city"] = LabelEncoder().fit_transform(df["city"])

df.head(10)
# Out:
#              price   bed  bath      street  city        state  zip_code  \
# 1414374 524900.000 3.000 2.000 1850809.000    56  Puerto Rico   602.000
# 1414376  90000.000 3.000 2.000  141421.000    57  Puerto Rico   603.000
# 1414377  22500.000 2.000 1.000 1889894.000   219  Puerto Rico   610.000
# 1414378 168000.000 6.000 4.000 1157317.000   219  Puerto Rico   610.000
# 1414379 200000.000 3.000 1.000 1855411.000   305  Puerto Rico   612.000
# 1414380 380000.000 2.000 2.000 1857001.000   305  Puerto Rico   612.000
# 1414382 250000.000 5.000 2.000 1946165.000   305  Puerto Rico   612.000
# 1414387 130000.000 3.000 1.000 1911843.000  1370  Puerto Rico   623.000
# 1414390 165000.000 2.000 1.000 1856948.000  1370  Puerto Rico   623.000
# 1414398 120000.000 4.000 2.000 1921908.000  8879  Puerto Rico   637.000
#
#          house_size
# 1414374    2200.000
# 1414376    1421.000
# 1414377     850.000
# 1414378    3422.000
# 1414379     580.000
# 1414380    1210.000
# 1414382    1210.000
# 1414387     847.000
# 1414390     696.000
# 1414398    1188.000

# %% [markdown]
# ### One hot encoding

# %% [markdown]
# #### Pandas
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html

# %%
data = pd.get_dummies(df, prefix=["state_"], columns=["state"])

data.head()
# Out:
#              price   bed  bath      street  city  zip_code  house_size  \
# 1414374 524900.000 3.000 2.000 1850809.000    56   602.000    2200.000
# 1414376  90000.000 3.000 2.000  141421.000    57   603.000    1421.000
# 1414377  22500.000 2.000 1.000 1889894.000   219   610.000     850.000
# 1414378 168000.000 6.000 4.000 1157317.000   219   610.000    3422.000
# 1414379 200000.000 3.000 1.000 1855411.000   305   612.000     580.000
#
#          state__Alabama  state__Arizona  state__Arkansas  ...  \
# 1414374           False           False            False  ...
# 1414376           False           False            False  ...
# 1414377           False           False            False  ...
# 1414378           False           False            False  ...
# 1414379           False           False            False  ...
#
#          state__Tennessee  state__Texas  state__Utah  state__Vermont  \
# 1414374             False         False        False           False
# 1414376             False         False        False           False
# 1414377             False         False        False           False
# 1414378             False         False        False           False
# 1414379             False         False        False           False
#
#          state__Virgin Islands  state__Virginia  state__Washington  \
# 1414374                  False            False              False
# 1414376                  False            False              False
# 1414377                  False            False              False
# 1414378                  False            False              False
# 1414379                  False            False              False
#
#          state__West Virginia  state__Wisconsin  state__Wyoming
# 1414374                 False             False           False
# 1414376                 False             False           False
# 1414377                 False             False           False
# 1414378                 False             False           False
# 1414379                 False             False           False
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Feature normalization

# %%
# Randomize the data
data = data.sample(frac=1).reset_index(drop=True)

# Split data into features and label
label = data["price"]
data = data.drop(columns=["price"])

# %%
from sklearn import preprocessing

# Standarize data
scaler = preprocessing.MinMaxScaler()

# fill missing values with 0
dataset = data.fillna(0)

dataset = pd.DataFrame(scaler.fit_transform(dataset), columns=dataset.columns)

dataset.head()
# Out:
#     bed  bath  street  city  zip_code  house_size  state__Alabama  \
# 0 0.250 0.375   0.014 0.129     0.303       0.003           0.000
# 1 0.250 0.125   0.675 0.025     0.705       0.002           0.000
# 2 0.250 0.000   0.900 0.075     0.354       0.001           1.000
# 3 0.375 0.125   0.343 0.641     0.557       0.002           0.000
# 4 0.000 0.000   0.916 0.788     0.947       0.001           0.000
#
#    state__Arizona  state__Arkansas  state__California  ...  state__Tennessee  \
# 0           0.000            0.000              0.000  ...             0.000
# 1           0.000            0.000              0.000  ...             0.000
# 2           0.000            0.000              0.000  ...             0.000
# 3           0.000            0.000              0.000  ...             0.000
# 4           0.000            0.000              1.000  ...             0.000
#
#    state__Texas  state__Utah  state__Vermont  state__Virgin Islands  \
# 0         0.000        0.000           0.000                  0.000
# 1         0.000        0.000           0.000                  0.000
# 2         0.000        0.000           0.000                  0.000
# 3         0.000        0.000           0.000                  0.000
# 4         0.000        0.000           0.000                  0.000
#
#    state__Virginia  state__Washington  state__West Virginia  state__Wisconsin  \
# 0            0.000              0.000                 0.000             0.000
# 1            0.000              0.000                 0.000             0.000
# 2            0.000              0.000                 0.000             0.000
# 3            0.000              0.000                 0.000             0.000
# 4            0.000              0.000                 0.000             0.000
#
#    state__Wyoming
# 0           0.000
# 1           0.000
# 2           0.000
# 3           0.000
# 4           0.000
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Dimensionality reduction

# %%
from sklearn.feature_selection import VarianceThreshold

print(dataset.shape)

# Remove features with low variance
selector = VarianceThreshold(threshold=0.01)
dataset = pd.DataFrame(selector.fit_transform(dataset), columns=dataset.columns[selector.get_support()])

print(dataset.shape)

dataset.head()
# Out:
# (608528, 57)
# (608528, 27)
#     bed  bath  street  city  zip_code  state__Arizona  state__California  \
# 0 0.250 0.375   0.014 0.129     0.303           0.000              0.000
# 1 0.250 0.125   0.675 0.025     0.705           0.000              0.000
# 2 0.250 0.000   0.900 0.075     0.354           0.000              0.000
# 3 0.375 0.125   0.343 0.641     0.557           0.000              0.000
# 4 0.000 0.000   0.916 0.788     0.947           0.000              1.000
#
#    state__Florida  state__Georgia  state__Illinois  ...  state__New York  \
# 0           0.000           1.000            0.000  ...            0.000
# 1           0.000           0.000            0.000  ...            0.000
# 2           0.000           0.000            0.000  ...            0.000
# 3           0.000           0.000            0.000  ...            0.000
# 4           0.000           0.000            0.000  ...            0.000
#
#    state__North Carolina  state__Ohio  state__Oklahoma  state__Oregon  \
# 0                  0.000        0.000            0.000          0.000
# 1                  0.000        0.000            0.000          0.000
# 2                  0.000        0.000            0.000          0.000
# 3                  0.000        0.000            0.000          0.000
# 4                  0.000        0.000            0.000          0.000
#
#    state__Pennsylvania  state__Texas  state__Virginia  state__Washington  \
# 0                0.000         0.000            0.000              0.000
# 1                0.000         0.000            0.000              0.000
# 2                0.000         0.000            0.000              0.000
# 3                0.000         0.000            0.000              0.000
# 4                0.000         0.000            0.000              0.000
#
#    state__Wisconsin
# 0             0.000
# 1             0.000
# 2             0.000
# 3             0.000
# 4             0.000
#
# [5 rows x 27 columns]

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Generate train and test datasets

# %%
# Generate train and test datasets'
from sklearn.model_selection import train_test_split

X = dataset
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=55)

X_train.head()
# Out:
#          bed  bath  street  city  zip_code  state__Arizona  state__California  \
# 521633 0.250 0.125   0.251 0.202     0.780           0.000              0.000
# 413918 0.125 0.000   0.247 0.781     0.635           0.000              0.000
# 174184 0.250 0.125   0.158 0.554     0.331           0.000              0.000
# 520957 0.250 0.250   0.053 0.996     0.238           0.000              0.000
# 575908 0.375 0.250   0.822 0.787     0.946           0.000              1.000
#
#         state__Florida  state__Georgia  state__Illinois  ...  state__New York  \
# 521633           0.000           0.000            0.000  ...            0.000
# 413918           0.000           0.000            0.000  ...            0.000
# 174184           1.000           0.000            0.000  ...            0.000
# 520957           0.000           0.000            0.000  ...            0.000
# 575908           0.000           0.000            0.000  ...            0.000
#
#         state__North Carolina  state__Ohio  state__Oklahoma  state__Oregon  \
# 521633                  0.000        0.000            0.000          0.000
# 413918                  0.000        0.000            0.000          0.000
# 174184                  0.000        0.000            0.000          0.000
# 520957                  0.000        0.000            0.000          0.000
# 575908                  0.000        0.000            0.000          0.000
#
#         state__Pennsylvania  state__Texas  state__Virginia  state__Washington  \
# 521633                0.000         1.000            0.000              0.000
# 413918                0.000         0.000            0.000              0.000
# 174184                0.000         0.000            0.000              0.000
# 520957                0.000         0.000            1.000              0.000
# 575908                0.000         0.000            0.000              0.000
#
#         state__Wisconsin
# 521633             0.000
# 413918             0.000
# 174184             0.000
# 520957             0.000
# 575908             0.000
#
# [5 rows x 27 columns]

# %%
y.head()
# Out:
# 0   527900.000
# 1   219000.000
# 2   120000.000
# 3   225000.000
# 4   825000.000
# Name: price, dtype: float64

# %% [markdown]
# # Train and evaluate models

# %%
# Train a Linear Regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

model1 = LinearRegression()
model1.fit(X_train, y_train)

y_pred = model1.predict(X_test)

print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("R2 Score: ", r2_score(y_test, y_pred))
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Explained Variance Score: ", explained_variance_score(y_test, y_pred))
# Out:
# Mean Squared Error:  177012562825.09674
# R2 Score:  0.397906615493161
# Mean Absolute Error:  222646.35233273127
# Explained Variance Score:  0.39791074751750466

# %%
# Train a Decision Tree Regressor model
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

model2 = XGBRegressor()
model2.fit(X_train, y_train)

y_pred = model2.predict(X_test)

print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("R2 Score: ", r2_score(y_test, y_pred))
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Explained Variance Score: ", explained_variance_score(y_test, y_pred))
# Out:
# Mean Squared Error:  87300263593.86206
# R2 Score:  0.7030554761951887
# Mean Absolute Error:  141382.34277066123
# Explained Variance Score:  0.7030555830444891

# %%
# Train a Neural Network model
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

model3 = MLPRegressor(
    hidden_layer_sizes=(100, 50),  # One hidden layer with 100 neurons
    activation="relu",  # 'relu' activation function
    solver="adam",  # 'adam' solver for weight optimization
    max_iter=500,  # Set the number of iterations (epochs)
    random_state=42,  # Set the seed for reproducibility
)
model3.fit(X_train, y_train)

y_pred = model3.predict(X_test)

print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("R2 Score: ", r2_score(y_test, y_pred))
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Explained Variance Score: ", explained_variance_score(y_test, y_pred))
# Out:
# Mean Squared Error:  146837689403.4055
# R2 Score:  0.500543916346678
# Mean Absolute Error:  191049.58211100174
# Explained Variance Score:  0.5005449879961086
# c:\Users\gibra\Downloads\Class #4 Data Preprocessing\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Compare y_pred and y_test
y_test = y_test.reset_index(drop=True)
y_pred = pd.Series(y_pred)

df = pd.DataFrame({"y_test": y_test, "y_pred": y_pred})
df["diff"] = df["y_test"] - df["y_pred"]

df.head(10)
# Out:
#        y_test      y_pred        diff
# 0  495000.000  802883.885 -307883.885
# 1  200000.000  193971.900    6028.100
# 2  429000.000  358423.457   70576.543
# 3  425000.000  456439.477  -31439.477
# 4 5988000.000 3514992.594 2473007.406
# 5  259900.000  165754.739   94145.261
# 6  305000.000  428931.944 -123931.944
# 7  295000.000  309298.541  -14298.541
# 8  363500.000  555800.513 -192300.513
# 9  369990.000  422074.854  -52084.854

# %% [markdown]
# ## Save the model

# %%
# Save the model

model2.save_model("model.json")

# %% [markdown]
# # Load the model

# %%
# Load the model
model2 = XGBRegressor()
model2.load_model("model.json")
